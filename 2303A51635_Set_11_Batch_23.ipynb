# %% [markdown]
# <a href="https://colab.research.google.com/github/sandesarikeerthi/keerthi/blob/main/2303A51635_Set_11_Batch_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "execution_count": 1,
      "metadata": {
        "id": "-KYbFg2TG6w2"
      },
      "outputs": [],
      "source": [
        "import pandas as pd\n",
        "import numpy as np\n",
        "from sklearn.model_selection import train_test_split\n",
        "from sklearn.ensemble import RandomForestClassifier\n",
        "from sklearn.metrics import accuracy_score, classification_report\n",
        "from sklearn.cluster import KMeans\n",
        "from sklearn.preprocessing import LabelEncoder"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "df = pd.read_csv('/content/ObesityDataSet_raw_and_data_sinthetic (1).csv')"
      ],
      "metadata": {
        "id": "P7t5eDLdHZLV"
      },
      "execution_count": 2,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "# Q1: Identify the top 5 reasons for obesity levels\n",
        "try:\n",
        "    reasons = df['Reasons_for_Obesity'].value_counts().head(5)\n",
        "    print(reasons)\n",
        "except KeyError:\n",
        "    print(\"Column 'Reasons_for_Obesity' not found in the DataFrame.\")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "_4s7AGLzHi-Z",
        "outputId": "1cb44fda-c4b6-48fa-d4fa-f7bd8cfd54d9"
      },
      "execution_count": 3,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Column 'Reasons_for_Obesity' not found in the DataFrame.\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "# Q2: Identify the age group with most obesity\n",
        "\n",
        "print(df.columns)\n",
        "\n",
        "\n",
        "age_group = df['Age'].value_counts().idxmax()\n",
        "print(f\"Age group with most obesity: {age_group}\")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "pXJOiZAlHmCi",
        "outputId": "156434f3-1ceb-4efc-c177-b81de757c21b"
      },
      "execution_count": 4,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',\n",
            "       'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',\n",
            "       'CALC', 'MTRANS', 'NObeyesdad'],\n",
            "      dtype='object')\n",
            "Age group with most obesity: 18.0\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "# Q3: Find the max and min weight of patient with obesity\n",
        "max_weight = df['Weight'].max() # Change 'weight' to 'Weight'\n",
        "min_weight = df['Weight'].min() # Change 'weight' to 'Weight'\n",
        "print(f\"Max Weight: {max_weight}, Min Weight: {min_weight}\")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "RIoMnFlxHowv",
        "outputId": "e5102dff-6001-43d4-c6c0-6d6b91bc7ee8"
      },
      "execution_count": 5,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Max Weight: 173.0, Min Weight: 39.0\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "# Q4: Name the top 5 eating habits contributing to obesityprint(df.columns)\n",
        "\n",
        "\n",
        "eating_habits = df['FAVC'].value_counts().head(5)  # Assuming the correct column name is 'FAVC'\n",
        "print(eating_habits)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "_ZecuiI_HrYY",
        "outputId": "a0cd33db-7a20-462b-b0f9-1048171441c7"
      },
      "execution_count": 6,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "FAVC\n",
            "yes    1866\n",
            "no      245\n",
            "Name: count, dtype: int64\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "# Q5: Identify the highest usage of tech gadgets among obese patients\n",
        "\n",
        "print(df.columns)\n",
        "\n",
        "\n",
        "tech_usage = df['CAEC'].value_counts().idxmax()  # Assuming the correct column name is 'CAEC'\n",
        "print(f\"Highest usage of tech gadgets: {tech_usage}\")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "I8Mx33YIHuHI",
        "outputId": "c7163c2d-bfa7-4469-ddff-319f6fa1fc77"
      },
      "execution_count": 7,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',\n",
            "       'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',\n",
            "       'CALC', 'MTRANS', 'NObeyesdad'],\n",
            "      dtype='object')\n",
            "Highest usage of tech gadgets: Sometimes\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "# Q6: Apply Classification Model to evaluate the dataset\n",
        "\n",
        "print(df.columns)\n",
        "\n",
        "y = df['NObeyesdad']  # Assuming the correct column name is 'NObeyesdad'"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "uA6MwN6GHxaJ",
        "outputId": "557c9c4f-69c5-4f07-dedb-07067c1cf02a"
      },
      "execution_count": 8,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',\n",
            "       'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',\n",
            "       'CALC', 'MTRANS', 'NObeyesdad'],\n",
            "      dtype='object')\n"
          ]
        }
      ]
    }
  ]
}
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': []},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'id': '-KYbFg2TG6w2'},
#    'outputs': [],
#    'source': ['import pandas as pd\n',
#     'import numpy as np\n',
#     'from sklearn.model_selection import train_test_split\n',
#     'from sklearn.ensemble import RandomForestClassifier\n',
#     'from sklearn.metrics import accuracy_score, classification_report\n',
#     'from sklearn.cluster import KMeans\n',
#     'from sklearn.preprocessing import LabelEncoder']},
#   {'cell_type': 'code',
#    'source': ["df = pd.read_csv('/content/ObesityDataSet_raw_and_data_sinthetic (1).csv')"],
#    'metadata': {'id': 'P7t5eDLdHZLV'},
#    'execution_count': 2,
#    'outputs': []},
#   {'cell_type': 'code',
# ...
